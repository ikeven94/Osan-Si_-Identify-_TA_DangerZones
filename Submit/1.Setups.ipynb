# %% [markdown]
# # 1. Setups

# %% [markdown]
# __Package Install__

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/app-root/lib/python3.6/site-packages (21.0)
# Collecting pip
#   Downloading pip-21.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 2.1 MB/s eta 0:00:01
#   Downloading pip-20.3.4-py2.py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 6.6 MB/s eta 0:00:01

# %%
import time
tried=0
while True:
    print("tries:",tried)
    # !pip install -r requirements.txt
    time.sleep(5)
    tried+=1
    if tried>5:break
        
# could not install packages due to an environmenterror errno 16 device or resource busy 에러가 가끔 발생. 
# 이를 위해 추가적으로 몇번 더 시도
# Out:
# tries: 0
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# tries: 1
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# tries: 2
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# tries: 3
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# tries: 4
# Requirement already satisfied: async-generator==1.10 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (1.10)
# Requirement already satisfied: attrs==20.3.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (20.3.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.9.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: bleach==3.2.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: branca==0.4.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: certifi==2020.12.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 7)) (2020.12.5)
# Requirement already satisfied: cffi==1.14.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 8)) (1.14.4)
# Requirement already satisfied: chardet==4.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: click==7.1.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 10)) (7.1.2)
# Requirement already satisfied: click-plugins==1.1.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: cligj==0.7.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: colorama==0.4.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 13)) (0.4.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 14)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 15)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 16)) (0.6.0)
# Requirement already satisfied: docopt==0.6.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 17)) (0.6.2)
# Requirement already satisfied: entrypoints==0.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 18)) (0.3)
# Requirement already satisfied: Fiona==1.8.8 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 19)) (1.8.8)
# Requirement already satisfied: folium==0.11.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 20)) (0.11.0)
# Requirement already satisfied: GDAL==3.1.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 21)) (3.1.2)
# Requirement already satisfied: geopandas==0.8.0+85.geabe404 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 22)) (0.8.0+85.geabe404)
# Requirement already satisfied: haversine==2.3.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 23)) (2.3.0)
# Requirement already satisfied: idna==2.10 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 24)) (2.10)
# Requirement already satisfied: ipykernel==5.4.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 25)) (5.4.2)
# Requirement already satisfied: ipython in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 26)) (7.16.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 27)) (0.2.0)
# Requirement already satisfied: jedi==0.18.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 28)) (0.18.0)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 29)) (2.11.2)
# Requirement already satisfied: joblib==1.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 30)) (1.0.0)
# Requirement already satisfied: Js2Py==0.70 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 31)) (0.70)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 32)) (3.2.0)
# Requirement already satisfied: jupyter==1.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 33)) (1.0.0)
# Requirement already satisfied: jupyter-client==6.1.7 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 34)) (6.1.7)
# Requirement already satisfied: jupyter-console==6.2.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 35)) (6.2.0)
# Requirement already satisfied: jupyter-core==4.7.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 36)) (4.7.0)
# Requirement already satisfied: jupyterlab-pygments==0.1.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 37)) (0.1.2)
# Requirement already satisfied: jupyterlab-widgets==1.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 38)) (1.0.0)
# Requirement already satisfied: kiwisolver==1.3.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 39)) (1.3.1)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 40)) (1.1.1)
# Requirement already satisfied: matplotlib==3.3.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 41)) (3.3.3)
# Requirement already satisfied: mistune==0.8.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 42)) (0.8.4)
# Requirement already satisfied: munch==2.5.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 43)) (2.5.0)
# Requirement already satisfied: nbclient==0.5.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 44)) (0.5.1)
# Requirement already satisfied: nbconvert==6.0.7 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 45)) (6.0.7)
# Requirement already satisfied: nbformat==5.0.8 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 46)) (5.0.8)
# Requirement already satisfied: nest-asyncio==1.4.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 47)) (1.4.3)
# Requirement already satisfied: notebook==6.1.6 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 48)) (6.1.6)
# Requirement already satisfied: numpy==1.19.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 49)) (1.19.1)
# Requirement already satisfied: packaging==20.8 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 50)) (20.8)
# Requirement already satisfied: pandas==1.1.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 51)) (1.1.5)
# Requirement already satisfied: pandocfilters==1.4.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 52)) (1.4.3)
# Requirement already satisfied: parso==0.8.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 53)) (0.8.1)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 54)) (0.7.5)
# Requirement already satisfied: Pillow==8.0.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 55)) (8.0.1)
# Requirement already satisfied: pipwin==0.5.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 56)) (0.5.0)
# Requirement already satisfied: prometheus-client==0.9.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 57)) (0.9.0)
# Requirement already satisfied: prompt-toolkit==3.0.8 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 58)) (3.0.8)
# Requirement already satisfied: pycparser==2.20 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 59)) (2.20)
# Requirement already satisfied: Pygments==2.7.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 60)) (2.7.3)
# Requirement already satisfied: pyjsparser==2.7.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 61)) (2.7.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 62)) (2.4.7)
# Requirement already satisfied: PyPrind==2.11.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 63)) (2.11.2)
# Requirement already satisfied: pyproj==2.6.1.post1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 64)) (2.6.1.post1)
# Requirement already satisfied: pyrsistent==0.17.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 65)) (0.17.3)
# Requirement already satisfied: pySmartDL==1.3.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 66)) (1.3.4)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 67)) (2.8.1)
# Requirement already satisfied: pytz==2020.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 68)) (2020.5)
# Requirement already satisfied: pyzmq==20.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 69)) (20.0.0)
# Requirement already satisfied: qtconsole==5.0.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 70)) (5.0.1)
# Requirement already satisfied: QtPy==1.9.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 71)) (1.9.0)
# Requirement already satisfied: requests==2.25.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 72)) (2.25.1)
# Requirement already satisfied: Rtree==0.9.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 73)) (0.9.4)
# Collecting scikit-learn==0.24.0
#   Downloading scikit_learn-0.24.0-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
#      |████████████████████████████████| 22.2 MB 13.9 MB/s eta 0:00:01
# Requirement already satisfied: scipy==1.4.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 75)) (1.4.1)
# Requirement already satisfied: seaborn==0.11.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 76)) (0.11.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 77)) (1.5.0)
# Collecting Shapely==1.7.0
#   Downloading Shapely-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 72.7 MB/s eta 0:00:01
# Requirement already satisfied: six==1.15.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 79)) (1.15.0)
# Requirement already satisfied: sklearn==0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 80)) (0.0)
# Requirement already satisfied: soupsieve==2.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 81)) (2.1)
# Requirement already satisfied: terminado==0.9.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 82)) (0.9.1)
# Requirement already satisfied: testpath==0.4.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 83)) (0.4.4)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 84)) (2.1.0)
# Requirement already satisfied: tornado==6.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 85)) (6.1)
# Requirement already satisfied: traitlets==4.3.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 86)) (4.3.2)
# Requirement already satisfied: tzlocal==2.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 87)) (2.1)
# Requirement already satisfied: urllib3==1.26.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 88)) (1.26.2)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 89)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 90)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 91)) (3.5.1)
# Requirement already satisfied: importlib-metadata in /opt/app-root/lib/python3.6/site-packages (from jsonschema==3.2.0->-r requirements.txt (line 32)) (1.7.0)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.6/site-packages (from jsonschema==3.2.0->-r requirements.txt (line 32)) (51.3.3)
# Requirement already satisfied: ipywidgets in /opt/app-root/lib/python3.6/site-packages (from jupyter==1.0.0->-r requirements.txt (line 33)) (7.6.2)
# Requirement already satisfied: argon2-cffi in /opt/app-root/lib/python3.6/site-packages (from notebook==6.1.6->-r requirements.txt (line 48)) (20.1.0)
# Requirement already satisfied: ptyprocess in /opt/app-root/lib/python3.6/site-packages (from terminado==0.9.1->-r requirements.txt (line 82)) (0.6.0)
# Requirement already satisfied: pexpect in /opt/app-root/lib/python3.6/site-packages (from ipython->-r requirements.txt (line 26)) (4.7.0)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.6/site-packages (from importlib-metadata->jsonschema==3.2.0->-r requirements.txt (line 32)) (3.1.0)
# Installing collected packages: Shapely, scikit-learn
#   Attempting uninstall: Shapely
#     Found existing installation: Shapely 1.7.1
#     Uninstalling Shapely-1.7.1:
#       Successfully uninstalled Shapely-1.7.1
# ERROR: Could not install packages due to an OSError: [Errno 16] Device or resource busy: '.nfs00000000c387fd990000003b'
#
# tries: 5
# Requirement already satisfied: async-generator==1.10 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (1.10)
# Requirement already satisfied: attrs==20.3.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (20.3.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.9.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: bleach==3.2.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: branca==0.4.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: certifi==2020.12.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 7)) (2020.12.5)
# Requirement already satisfied: cffi==1.14.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 8)) (1.14.4)
# Requirement already satisfied: chardet==4.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: click==7.1.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 10)) (7.1.2)
# Requirement already satisfied: click-plugins==1.1.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: cligj==0.7.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: colorama==0.4.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 13)) (0.4.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 14)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 15)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 16)) (0.6.0)
# Requirement already satisfied: docopt==0.6.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 17)) (0.6.2)
# Requirement already satisfied: entrypoints==0.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 18)) (0.3)
# Requirement already satisfied: Fiona==1.8.8 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 19)) (1.8.8)
# Requirement already satisfied: folium==0.11.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 20)) (0.11.0)
# Requirement already satisfied: GDAL==3.1.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 21)) (3.1.2)
# Requirement already satisfied: geopandas==0.8.0+85.geabe404 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 22)) (0.8.0+85.geabe404)
# Requirement already satisfied: haversine==2.3.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 23)) (2.3.0)
# Requirement already satisfied: idna==2.10 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 24)) (2.10)
# Requirement already satisfied: ipykernel==5.4.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 25)) (5.4.2)
# Requirement already satisfied: ipython in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 26)) (7.16.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 27)) (0.2.0)
# Requirement already satisfied: jedi==0.18.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 28)) (0.18.0)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 29)) (2.11.2)
# Requirement already satisfied: joblib==1.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 30)) (1.0.0)
# Requirement already satisfied: Js2Py==0.70 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 31)) (0.70)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 32)) (3.2.0)
# Requirement already satisfied: jupyter==1.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 33)) (1.0.0)
# Requirement already satisfied: jupyter-client==6.1.7 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 34)) (6.1.7)
# Requirement already satisfied: jupyter-console==6.2.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 35)) (6.2.0)
# Requirement already satisfied: jupyter-core==4.7.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 36)) (4.7.0)
# Requirement already satisfied: jupyterlab-pygments==0.1.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 37)) (0.1.2)
# Requirement already satisfied: jupyterlab-widgets==1.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 38)) (1.0.0)
# Requirement already satisfied: kiwisolver==1.3.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 39)) (1.3.1)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 40)) (1.1.1)
# Requirement already satisfied: matplotlib==3.3.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 41)) (3.3.3)
# Requirement already satisfied: mistune==0.8.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 42)) (0.8.4)
# Requirement already satisfied: munch==2.5.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 43)) (2.5.0)
# Requirement already satisfied: nbclient==0.5.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 44)) (0.5.1)
# Requirement already satisfied: nbconvert==6.0.7 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 45)) (6.0.7)
# Requirement already satisfied: nbformat==5.0.8 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 46)) (5.0.8)
# Requirement already satisfied: nest-asyncio==1.4.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 47)) (1.4.3)
# Requirement already satisfied: notebook==6.1.6 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 48)) (6.1.6)
# Requirement already satisfied: numpy==1.19.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 49)) (1.19.1)
# Requirement already satisfied: packaging==20.8 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 50)) (20.8)
# Requirement already satisfied: pandas==1.1.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 51)) (1.1.5)
# Requirement already satisfied: pandocfilters==1.4.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 52)) (1.4.3)
# Requirement already satisfied: parso==0.8.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 53)) (0.8.1)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 54)) (0.7.5)
# Requirement already satisfied: Pillow==8.0.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 55)) (8.0.1)
# Requirement already satisfied: pipwin==0.5.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 56)) (0.5.0)
# Requirement already satisfied: prometheus-client==0.9.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 57)) (0.9.0)
# Requirement already satisfied: prompt-toolkit==3.0.8 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 58)) (3.0.8)
# Requirement already satisfied: pycparser==2.20 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 59)) (2.20)
# Requirement already satisfied: Pygments==2.7.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 60)) (2.7.3)
# Requirement already satisfied: pyjsparser==2.7.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 61)) (2.7.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 62)) (2.4.7)
# Requirement already satisfied: PyPrind==2.11.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 63)) (2.11.2)
# Requirement already satisfied: pyproj==2.6.1.post1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 64)) (2.6.1.post1)
# Requirement already satisfied: pyrsistent==0.17.3 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 65)) (0.17.3)
# Requirement already satisfied: pySmartDL==1.3.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 66)) (1.3.4)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 67)) (2.8.1)
# Requirement already satisfied: pytz==2020.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 68)) (2020.5)
# Requirement already satisfied: pyzmq==20.0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 69)) (20.0.0)
# Requirement already satisfied: qtconsole==5.0.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 70)) (5.0.1)
# Requirement already satisfied: QtPy==1.9.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 71)) (1.9.0)
# Requirement already satisfied: requests==2.25.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 72)) (2.25.1)
# Requirement already satisfied: Rtree==0.9.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 73)) (0.9.4)
# Collecting scikit-learn==0.24.0
#   Downloading scikit_learn-0.24.0-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
#      |████████████████████████████████| 22.2 MB 24.8 MB/s eta 0:00:01
# Requirement already satisfied: scipy==1.4.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 75)) (1.4.1)
# Requirement already satisfied: seaborn==0.11.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 76)) (0.11.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 77)) (1.5.0)
# Requirement already satisfied: Shapely==1.7.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 78)) (1.7.0)
# Requirement already satisfied: six==1.15.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 79)) (1.15.0)
# Requirement already satisfied: sklearn==0.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 80)) (0.0)
# Requirement already satisfied: soupsieve==2.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 81)) (2.1)
# Requirement already satisfied: terminado==0.9.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 82)) (0.9.1)
# Requirement already satisfied: testpath==0.4.4 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 83)) (0.4.4)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 84)) (2.1.0)
# Requirement already satisfied: tornado==6.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 85)) (6.1)
# Requirement already satisfied: traitlets==4.3.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 86)) (4.3.2)
# Requirement already satisfied: tzlocal==2.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 87)) (2.1)
# Requirement already satisfied: urllib3==1.26.2 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 88)) (1.26.2)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 89)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 90)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/app-root/lib/python3.6/site-packages (from -r requirements.txt (line 91)) (3.5.1)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.6/site-packages (from jsonschema==3.2.0->-r requirements.txt (line 32)) (51.3.3)
# Requirement already satisfied: importlib-metadata in /opt/app-root/lib/python3.6/site-packages (from jsonschema==3.2.0->-r requirements.txt (line 32)) (1.7.0)
# Requirement already satisfied: ipywidgets in /opt/app-root/lib/python3.6/site-packages (from jupyter==1.0.0->-r requirements.txt (line 33)) (7.6.2)
# Requirement already satisfied: argon2-cffi in /opt/app-root/lib/python3.6/site-packages (from notebook==6.1.6->-r requirements.txt (line 48)) (20.1.0)
# Requirement already satisfied: ptyprocess in /opt/app-root/lib/python3.6/site-packages (from terminado==0.9.1->-r requirements.txt (line 82)) (0.6.0)
# Requirement already satisfied: pexpect in /opt/app-root/lib/python3.6/site-packages (from ipython->-r requirements.txt (line 26)) (4.7.0)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.6/site-packages (from importlib-metadata->jsonschema==3.2.0->-r requirements.txt (line 32)) (3.1.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
# ERROR: Could not install packages due to an OSError: [Errno 16] Device or resource busy: '.nfs00000000c381252f0000003c'

# %% [markdown]
# __Font Install__

# %%
# !cp /opt/app-root/src/malgun.ttf /opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/

# %%
# !rm -rf /opt/app-root/src/.cache/matplotlib/*

# %%
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")

#Font
import matplotlib
from matplotlib import font_manager
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")
matplotlib.rcParams['axes.unicode_minus']=False

font_fname = '/opt/app-root/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/malgun.ttf'
font_family = font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"] = font_family
print("Font set to :",plt.rcParams["font.family"])
# Out:
# Font set to : ['Malgun Gothic']
