# %%
from geoband.API import *

# %%
import folium
import json
import geopandas as gpd

# %%
import numpy as np
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
import json
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
from sklearn.cluster import KMeans
import seaborn as sns
# Out:
# /opt/app-root/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### API로 데이터 불러오기

# %%
# API로 데이터 불러오기 
GetCompasData('SBJ_2012_001', '1', '1.오산시_주정차단속(2018~2020).csv')
GetCompasData('SBJ_2012_001', '2', '2.오산시_어린이교통사고_격자.geojson')
GetCompasData('SBJ_2012_001', '3', '3.오산시_차량등록현황_격자.geojson')
GetCompasData('SBJ_2012_001', '4', '4.오산시_연령별_거주인구격자(총인구).geojson')
GetCompasData('SBJ_2012_001', '5', '5.오산시_연령별_거주인구격자(유소년).geojson')
GetCompasData('SBJ_2012_001', '6', '6.오산시_연령별_거주인구격자(생산가능인구).geojson')
GetCompasData('SBJ_2012_001', '7', '7.오산시_연령별_거주인구격자(고령).geojson')
GetCompasData('SBJ_2012_001', '8', '8.오산시_유동인구(2019).csv')

GetCompasData('SBJ_2012_001', '9', '9.오산시_어린이보호구역.csv')
GetCompasData('SBJ_2012_001', '10', '10.오산시_학교위치정보.csv')
GetCompasData('SBJ_2012_001', '11', '11.오산시_초등학교_통학구.geojson')
GetCompasData('SBJ_2012_001', '12', '12.오산시_중학교_학군.geojson')
GetCompasData('SBJ_2012_001', '13', '13.오산시_어린이집_유치원현황.csv')

GetCompasData('SBJ_2012_001', '14', '14.오산시_기상데이터(2010~2019).csv')

GetCompasData('SBJ_2012_001', '15', '15.오산시_무인교통단속카메라.csv')
GetCompasData('SBJ_2012_001', '16', '16.오산시_도로안전표지표준데이터.csv')
GetCompasData('SBJ_2012_001', '17', '17.오산시_횡단보도.geojson')
GetCompasData('SBJ_2012_001', '18', '18.오산시_과속방지턱표준데이터.csv')
GetCompasData('SBJ_2012_001', '19', '19.오산시_신호등.geojson')
GetCompasData('SBJ_2012_001', '20', '20.오산시_CCTV설치현황.csv')

GetCompasData('SBJ_2012_001', '21', '21.오산시_인도.geojson')
GetCompasData('SBJ_2012_001', '22', '22.오산시_버스정류장.csv')

GetCompasData('SBJ_2012_001', '23', '23.오산시_상세도로망_LV6.geojson')
GetCompasData('SBJ_2012_001', '24', '24.평일_전일,시간대별_오산시_추정교통량_Level6.csv')
GetCompasData('SBJ_2012_001', '25', '25.평일_전일_오산시_혼잡빈도강도_Level6.csv')
GetCompasData('SBJ_2012_001', '26', '26.평일_전일_오산시_혼잡시간강도_Level6.csv')

GetCompasData('SBJ_2012_001', '27', '27.오산시_도로명주소_건물.geojson')
GetCompasData('SBJ_2012_001', '28', '28.오산시_건물연면적_격자.geojson')

GetCompasData('SBJ_2012_001', '29', '29.오산시_체육시설현황.csv')
GetCompasData('SBJ_2012_001', '30', '30.오산시_학원_및_교습소_현황.csv')

GetCompasData('SBJ_2012_001', '31', '31.오산시_법정경계(시군구).geojson')
GetCompasData('SBJ_2012_001', '32', '32.오산시_행정경계(읍면동).geojson')
GetCompasData('SBJ_2012_001', '33', '33.오산시_법정경계(읍면동).geojson')

GetCompasData('SBJ_2012_001', '34', '34.오산시_지적도.geojson')

# %% [markdown]
# ## 1. 주정차 단속 데이터 확인 및 전처리

# %%
주정차단속 = pd.read_csv('1.오산시_주정차단속(2018~2020).csv')

# %%
주정차단속
# 61701개 행, 7 column의 데이터
# Out:
#            단속일자            단속위치         행정구역 스쿨존여부     단속위치_경도    단속위치_위도  \
# 0      20181101     금암동 여계산로 부근  경기도 오산시 세교동     N  127.043462  37.170237
# 1      20181101    세교동 세마역로19번길  경기도 오산시 세교동     N  127.044770  37.181695
# 2      20181101     세교동 수목원로 부근  경기도 오산시 양산동     N  127.042200  37.186357
# 3      20181101  오산동 오산로272번길 부   경기도 오산시 원동     N  127.071732  37.150557
# 4      20181101    오산동 성호대로93번길  경기도 오산시 부산동     N  127.071757  37.150457
# ...         ...             ...          ...   ...         ...        ...
# 61696  20201111   GS25궐동대호점 맞은편  경기도 오산시 청학동     N  127.053064  37.158140
# 61697  20201111          물향기지하도   경기도 오산시 원동     N  127.066157  37.171143
# 61698  20201111    운암2단지 근린공원삼거  경기도 오산시 청호동     N  127.077283  37.158126
# 61699  20201111    궐동 양평해장국 사거리   경기도 오산시 궐동     N  127.056665  37.155827
# 61700  20201111    어울림(북개천) 사거리  경기도 오산시 부산동     N  127.068644  37.143810
#
#             단속종류
# 0      이동형CCTV단속
# 1      이동형CCTV단속
# 2      이동형CCTV단속
# 3      이동형CCTV단속
# 4      이동형CCTV단속
# ...          ...
# 61696  고정형CCTV단속
# 61697  고정형CCTV단속
# 61698  고정형CCTV단속
# 61699  고정형CCTV단속
# 61700  고정형CCTV단속
#
# [61701 rows x 7 columns]

# %%
# 오산시가 아닌 결측치가 확인된다.
# (경기도, 충청도, 전라도 등등)
주정차단속['행정구역'].value_counts()
# Out:
# 경기도 오산시 궐동              12494
# 경기도 오산시 원동               8597
# 경기도 오산시 금암동              5936
# 경기도 오산시 오산동              5289
# 경기도 오산시 수청동              4289
# 경기도 오산시 내삼미동             3979
# 경기도 오산시 부산동              2971
# 경기도 오산시 갈곶동              2660
# 경기도 오산시 세교동              1918
# 경기도 오산시 지곶동              1707
# 경기도 오산시 누읍동              1596
# 경기도 오산시 은계동              1582
# 경기도 오산시 청호동              1442
# 경기도 오산시 가수동              1230
# 경기도 오산시 양산동              1217
# 경기도 오산시 서동               1192
# 경기도 오산시 청학동               901
# 경기도 오산시 고현동               759
# 경기도 화성시 오산동               636
# 경기도 오산시 외삼미동              632
# 경기도 오산시 가장동               261
# 경기도 오산시 두곡동               106
# 경기도 오산시 벌음동                94
# 경기도 오산시 탑동                 93
# 경기도 오산시 서랑동                88
# 충청북도 청주시 흥덕구 옥산면 오산리        9
# 경상북도 청도군 각북면 오산리            7
# 충청북도 음성군 대소면 오산리            5
# 전라북도 무주군 무주읍 오산리            3
# 경기도 용인시 처인구 모현읍 오산리         2
# 경기도 안성시 금광면 오산리             1
# 전라남도 곡성군 오산면                1
# 경기도 파주시 조리읍 오산리             1
# 전라북도 익산시 오산면 영만리            1
# 경기도 양주시 백석읍 오산리             1
# 전라북도 익산시 오산면                1
# Name: 행정구역, dtype: int64

# %%
주정차단속 = 주정차단속[주정차단속['행정구역'].str.contains('경기도 오산시')]
주정차단속
# 기존의 61701 >>  61033
# Out:
#            단속일자            단속위치         행정구역 스쿨존여부     단속위치_경도    단속위치_위도  \
# 0      20181101     금암동 여계산로 부근  경기도 오산시 세교동     N  127.043462  37.170237
# 1      20181101    세교동 세마역로19번길  경기도 오산시 세교동     N  127.044770  37.181695
# 2      20181101     세교동 수목원로 부근  경기도 오산시 양산동     N  127.042200  37.186357
# 3      20181101  오산동 오산로272번길 부   경기도 오산시 원동     N  127.071732  37.150557
# 4      20181101    오산동 성호대로93번길  경기도 오산시 부산동     N  127.071757  37.150457
# ...         ...             ...          ...   ...         ...        ...
# 61696  20201111   GS25궐동대호점 맞은편  경기도 오산시 청학동     N  127.053064  37.158140
# 61697  20201111          물향기지하도   경기도 오산시 원동     N  127.066157  37.171143
# 61698  20201111    운암2단지 근린공원삼거  경기도 오산시 청호동     N  127.077283  37.158126
# 61699  20201111    궐동 양평해장국 사거리   경기도 오산시 궐동     N  127.056665  37.155827
# 61700  20201111    어울림(북개천) 사거리  경기도 오산시 부산동     N  127.068644  37.143810
#
#             단속종류
# 0      이동형CCTV단속
# 1      이동형CCTV단속
# 2      이동형CCTV단속
# 3      이동형CCTV단속
# 4      이동형CCTV단속
# ...          ...
# 61696  고정형CCTV단속
# 61697  고정형CCTV단속
# 61698  고정형CCTV단속
# 61699  고정형CCTV단속
# 61700  고정형CCTV단속
#
# [61033 rows x 7 columns]

# %% [markdown]
# ## 2.어린이 교통사고 격자

# %%
교통사고grid = gpd.read_file('2.오산시_어린이교통사고_격자.geojson')
교통사고grid
# Out:
#            gid  accident_cnt  \
# 0     다사551085             0
# 1     다사551086             0
# 2     다사551087             0
# 3     다사551088             0
# 4     다사552085             0
# ...        ...           ...
# 4505  다사646052             0
# 4506  다사646053             0
# 4507  다사647050             0
# 4508  다사647051             0
# 4509  다사647052             0
#
#                                                geometry
# 0     MULTIPOLYGON (((126.99422 37.17418, 126.99421 ...
# 1     MULTIPOLYGON (((126.99421 37.17508, 126.99420 ...
# 2     MULTIPOLYGON (((126.99420 37.17599, 126.99420 ...
# 3     MULTIPOLYGON (((126.99420 37.17689, 126.99419 ...
# 4     MULTIPOLYGON (((126.99534 37.17419, 126.99534 ...
# ...                                                 ...
# 4505  MULTIPOLYGON (((127.10138 37.14484, 127.10138 ...
# 4506  MULTIPOLYGON (((127.10138 37.14575, 127.10137 ...
# 4507  MULTIPOLYGON (((127.10252 37.14305, 127.10251 ...
# 4508  MULTIPOLYGON (((127.10251 37.14395, 127.10251 ...
# 4509  MULTIPOLYGON (((127.10251 37.14485, 127.10250 ...
#
# [4510 rows x 3 columns]

# %%
교통사고grid['accident_cnt'].value_counts()
# 상습적으로 어린이 교통사고가 이루어지는곳들을 찾아보자!
# Out:
# 0     4165
# 1      238
# 2       63
# 3       25
# 5        7
# 4        7
# 6        3
# 7        1
# 10       1
# Name: accident_cnt, dtype: int64

# %%
acc3 = 교통사고grid[교통사고grid['accident_cnt'] >= 3 ] # 3번이상 교통사고 일어난 곳
acc3
# Out:
#            gid  accident_cnt  \
# 1752  다사594107             3
# 1810  다사595085             3
# 1812  다사595087             4
# 1892  다사596087             3
# 1968  다사597088             3
# 2003  다사598048             3
# 2044  다사598089             3
# 2265  다사601084             3
# 2417  다사603087             3
# 2689  다사607068             3
# 2710  다사607089             3
# 2763  다사608068             4
# 2902  다사610057             5
# 2925  다사610080             5
# 3058  다사612061             3
# 3098  다사612101             6
# 3131  다사613057             3
# 3145  다사613071             3
# 3211  다사614056             3
# 3212  다사614057             3
# 3236  다사614081             4
# 3358  다사616051             3
# 3370  다사616063             5
# 3415  다사617039             4
# 3483  다사618039             3
# 3617  다사620042             7
# 3639  다사620064             5
# 3678  다사621045             3
# 3681  다사621048            10
# 3686  다사621053             3
# 3689  다사621056             5
# 3737  다사622056             4
# 3778  다사623053             3
# 3782  다사623057             3
# 3828  다사624061             6
# 3831  다사624064             3
# 3849  다사625042             5
# 3850  다사625043             5
# 3863  다사625056             6
# 3869  다사625062             3
# 3871  다사625064             3
# 3874  다사625067             4
# 3932  다사627042             4
# 4155  다사632067             3
#
#                                                geometry
# 1752  MULTIPOLYGON (((127.04253 37.19421, 127.04253 ...
# 1810  MULTIPOLYGON (((127.04378 37.17438, 127.04377 ...
# 1812  MULTIPOLYGON (((127.04377 37.17619, 127.04376 ...
# 1892  MULTIPOLYGON (((127.04489 37.17619, 127.04489 ...
# 1968  MULTIPOLYGON (((127.04602 37.17710, 127.04601 ...
# 2003  MULTIPOLYGON (((127.04736 37.14105, 127.04735 ...
# 2044  MULTIPOLYGON (((127.04714 37.17800, 127.04713 ...
# 2265  MULTIPOLYGON (((127.05054 37.17351, 127.05054 ...
# 2417  MULTIPOLYGON (((127.05278 37.17622, 127.05277 ...
# 2689  MULTIPOLYGON (((127.05739 37.15911, 127.05738 ...
# 2710  MULTIPOLYGON (((127.05728 37.17804, 127.05727 ...
# 2763  MULTIPOLYGON (((127.05851 37.15912, 127.05851 ...
# 2902  MULTIPOLYGON (((127.06082 37.14921, 127.06082 ...
# 2925  MULTIPOLYGON (((127.06070 37.16994, 127.06070 ...
# 3058  MULTIPOLYGON (((127.06305 37.15282, 127.06305 ...
# 3098  MULTIPOLYGON (((127.06285 37.18888, 127.06284 ...
# 3131  MULTIPOLYGON (((127.06420 37.14922, 127.06419 ...
# 3145  MULTIPOLYGON (((127.06413 37.16184, 127.06412 ...
# 3211  MULTIPOLYGON (((127.06533 37.14832, 127.06533 ...
# 3212  MULTIPOLYGON (((127.06533 37.14923, 127.06532 ...
# 3236  MULTIPOLYGON (((127.06520 37.17086, 127.06520 ...
# 3358  MULTIPOLYGON (((127.06761 37.14382, 127.06760 ...
# 3370  MULTIPOLYGON (((127.06755 37.15464, 127.06754 ...
# 3415  MULTIPOLYGON (((127.06880 37.13301, 127.06879 ...
# 3483  MULTIPOLYGON (((127.06992 37.13302, 127.06992 ...
# 3617  MULTIPOLYGON (((127.07216 37.13573, 127.07215 ...
# 3639  MULTIPOLYGON (((127.07205 37.15556, 127.07204 ...
# 3678  MULTIPOLYGON (((127.07327 37.13844, 127.07326 ...
# 3681  MULTIPOLYGON (((127.07325 37.14114, 127.07325 ...
# 3686  MULTIPOLYGON (((127.07323 37.14565, 127.07322 ...
# 3689  MULTIPOLYGON (((127.07321 37.14835, 127.07321 ...
# 3737  MULTIPOLYGON (((127.07434 37.14836, 127.07433 ...
# 3778  MULTIPOLYGON (((127.07548 37.14566, 127.07548 ...
# 3782  MULTIPOLYGON (((127.07546 37.14926, 127.07546 ...
# 3828  MULTIPOLYGON (((127.07657 37.15287, 127.07656 ...
# 3831  MULTIPOLYGON (((127.07655 37.15558, 127.07655 ...
# 3849  MULTIPOLYGON (((127.07779 37.13575, 127.07778 ...
# 3850  MULTIPOLYGON (((127.07778 37.13665, 127.07778 ...
# 3863  MULTIPOLYGON (((127.07772 37.14837, 127.07771 ...
# 3869  MULTIPOLYGON (((127.07769 37.15378, 127.07768 ...
# 3871  MULTIPOLYGON (((127.07768 37.15558, 127.07767 ...
# 3874  MULTIPOLYGON (((127.07766 37.15828, 127.07766 ...
# 3932  MULTIPOLYGON (((127.08004 37.13576, 127.08003 ...
# 4155  MULTIPOLYGON (((127.08555 37.15831, 127.08554 ...

# %%
acc3.geometry
# Out:
# 1752    MULTIPOLYGON (((127.04253 37.19421, 127.04253 ...
# 1810    MULTIPOLYGON (((127.04378 37.17438, 127.04377 ...
# 1812    MULTIPOLYGON (((127.04377 37.17619, 127.04376 ...
# 1892    MULTIPOLYGON (((127.04489 37.17619, 127.04489 ...
# 1968    MULTIPOLYGON (((127.04602 37.17710, 127.04601 ...
# 2003    MULTIPOLYGON (((127.04736 37.14105, 127.04735 ...
# 2044    MULTIPOLYGON (((127.04714 37.17800, 127.04713 ...
# 2265    MULTIPOLYGON (((127.05054 37.17351, 127.05054 ...
# 2417    MULTIPOLYGON (((127.05278 37.17622, 127.05277 ...
# 2689    MULTIPOLYGON (((127.05739 37.15911, 127.05738 ...
# 2710    MULTIPOLYGON (((127.05728 37.17804, 127.05727 ...
# 2763    MULTIPOLYGON (((127.05851 37.15912, 127.05851 ...
# 2902    MULTIPOLYGON (((127.06082 37.14921, 127.06082 ...
# 2925    MULTIPOLYGON (((127.06070 37.16994, 127.06070 ...
# 3058    MULTIPOLYGON (((127.06305 37.15282, 127.06305 ...
# 3098    MULTIPOLYGON (((127.06285 37.18888, 127.06284 ...
# 3131    MULTIPOLYGON (((127.06420 37.14922, 127.06419 ...
# 3145    MULTIPOLYGON (((127.06413 37.16184, 127.06412 ...
# 3211    MULTIPOLYGON (((127.06533 37.14832, 127.06533 ...
# 3212    MULTIPOLYGON (((127.06533 37.14923, 127.06532 ...
# 3236    MULTIPOLYGON (((127.06520 37.17086, 127.06520 ...
# 3358    MULTIPOLYGON (((127.06761 37.14382, 127.06760 ...
# 3370    MULTIPOLYGON (((127.06755 37.15464, 127.06754 ...
# 3415    MULTIPOLYGON (((127.06880 37.13301, 127.06879 ...
# 3483    MULTIPOLYGON (((127.06992 37.13302, 127.06992 ...
# 3617    MULTIPOLYGON (((127.07216 37.13573, 127.07215 ...
# 3639    MULTIPOLYGON (((127.07205 37.15556, 127.07204 ...
# 3678    MULTIPOLYGON (((127.07327 37.13844, 127.07326 ...
# 3681    MULTIPOLYGON (((127.07325 37.14114, 127.07325 ...
# 3686    MULTIPOLYGON (((127.07323 37.14565, 127.07322 ...
# 3689    MULTIPOLYGON (((127.07321 37.14835, 127.07321 ...
# 3737    MULTIPOLYGON (((127.07434 37.14836, 127.07433 ...
# 3778    MULTIPOLYGON (((127.07548 37.14566, 127.07548 ...
# 3782    MULTIPOLYGON (((127.07546 37.14926, 127.07546 ...
# 3828    MULTIPOLYGON (((127.07657 37.15287, 127.07656 ...
# 3831    MULTIPOLYGON (((127.07655 37.15558, 127.07655 ...
# 3849    MULTIPOLYGON (((127.07779 37.13575, 127.07778 ...
# 3850    MULTIPOLYGON (((127.07778 37.13665, 127.07778 ...
# 3863    MULTIPOLYGON (((127.07772 37.14837, 127.07771 ...
# 3869    MULTIPOLYGON (((127.07769 37.15378, 127.07768 ...
# 3871    MULTIPOLYGON (((127.07768 37.15558, 127.07767 ...
# 3874    MULTIPOLYGON (((127.07766 37.15828, 127.07766 ...
# 3932    MULTIPOLYGON (((127.08004 37.13576, 127.08003 ...
# 4155    MULTIPOLYGON (((127.08555 37.15831, 127.08554 ...
# Name: geometry, dtype: geometry

# %%
acc3.iloc[0].geometry

# %%
acc3.iloc[0]
# Out:
# gid                                                      다사594107
# accident_cnt                                                    3
# geometry        (POLYGON ((127.0425327222538 37.19420970044549...
# Name: 1752, dtype: object

# %%
# 3번 이상 교통사고가 일어난 곳은 대부분 교차로!!!
center = [37.163619, 127.049883]
m = folium.Map(location=center, tiles='openstreetmap', zoom_start=12.8) #'cartodbpositron'
folium.GeoJson(acc3['geometry']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 5번이상 교통사고 일어난 곳 >>> 교차로 중에서도 전부 대로!!!
acc5 = 교통사고grid[교통사고grid['accident_cnt'] >= 5 ] 
center = [37.163619, 127.049883]
m = folium.Map(location=center, tiles='openstreetmap', zoom_start=12.8) #'cartodbpositron'
folium.GeoJson(acc5['geometry']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
acc7 = 교통사고grid[교통사고grid['accident_cnt'] >= 7 ]
acc10 = 교통사고grid[교통사고grid['accident_cnt'] == 10 ]

# %%
center = [37.163619, 127.049883]
m = folium.Map(location=center, tiles='openstreetmap', zoom_start=13, fill_color='BuPu') #'cartodbpositron'

folium.GeoJson(acc3['geometry'],
              style_function = lambda x: {
                  'color': 'green',
                  'weight': 1.5,
                  'fillOpacity': 0.3,
              }).add_to(m)
folium.GeoJson(acc5['geometry'],
              style_function = lambda x: {
                  'color': 'blue',
                  'weight': 1.5,
                  'fillOpacity': 0.3,
              }).add_to(m)
folium.GeoJson(acc7['geometry'],
              style_function = lambda x: {
                  'color': 'red',
                  'weight': 1.5,
                  'fillOpacity': 0.3,
              }).add_to(m)
folium.GeoJson(acc10['geometry'],
              style_function = lambda x: {
                  'color': 'black',
                  'weight': 1.5,
                  'fillOpacity': 0.3,
              }).add_to(m)
#folium.LatLngPopup().add_to(m)

# %%
m
# green : 3회이상 blue : 5회이상 red : 7회이상 balck :10회 (최다)
# 눈으로 확인하니 교차로가 많이 보인다!!
# 교차로와의 연관 지어보자 
# 사고난 교차로의 도로 폭도 구해보기
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 9. 어린이 보호구역

# %%
'''
- 어린이보호구역

초등학교 및 유치원 정문에서 내의 주반경 300m 이통학로를 보호구역으로 지정하여 교통안전시설물 및 도로부속물설치로 
학생들의 안전한 통학공간을 확보하여 교통사고를 예방하기 위한 제도로 ' 스쿨존(school Zone)'이라고도 합니다.

- 보호구역안에서 학생들의 등하교시간에 자동차의 통행을 금지하거나 제한할 수 있으며, 
자동차의 정차나 주차를 금지할 수 있고, 운행속도를 30km이내로 제한 할 수 있습니다.

# 반드시 30km 미만 주행
# 불법 주정차 금지
'''

# %%
보호구역 = pd.read_csv('9.오산시_어린이보호구역.csv')
보호구역
# Out:
#     시설종류         시설명 CCTV설치여부  CCTV설치대수  보호구역도로폭     보호구역_경도    보호구역_위도
# 0   특수학교        성심학교        N         0       25  127.017521  37.176762
# 1   초등학교      가수초등학교        Y         1       12  127.047957  37.148103
# 2   초등학교      광성초등학교        Y         2       12  127.039709  37.184197
# 3   초등학교      대호초등학교        Y         3       12  127.057889  37.159106
# 4   초등학교      매홀초등학교        Y         2        6  127.063282  37.162749
# ..   ...         ...      ...       ...      ...         ...        ...
# 86  어린이집    시립세마어린이집        Y         1       12  127.044916  37.184608
# 87  어린이집     미래숲어린이집        Y         1        6  127.044384  37.145326
# 88  어린이집   시립은여울어린이집        N         0       20  127.066860  37.170952
# 89  어린이집     설리반어린이집        N         0        5  127.061041  37.164127
# 90  어린이집  세교복지타운어린이집        Y         1       15  127.044835  37.177752
#
# [91 rows x 7 columns]

# %%
# 일반적으로 도로폭 20 이상일 떄 보차 구분 있음
# 10, 12 도로폭이 일반적으로 주택가에서 접할 수 있는 보차 구분 없는 도로

# 보차 구분 없는 도로일 때 더 위험하지 않을까??? 
# 분석 해봐야겠지만 큰 차이가 없다면 기존 보호구역에서 보차 구분 없는곳에 방지턱 등등을 설치하는게 좋지 않을까

# %%
protect_spot = 보호구역[['시설종류','보호구역_경도','보호구역_위도']]
ps = protect_spot['시설종류'].value_counts()
ps
# Out:
# 어린이집    48
# 초등학교    25
# 유치원     17
# 특수학교     1
# Name: 시설종류, dtype: int64

# %%
ps.plot(kind='barh')
# Out:
# <AxesSubplot:>
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 47536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 47536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 51665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50976 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/app-root/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
m2 = m

# %%
# 어린이 사고격자  + 보호구역

for i in protect_spot.index:
    folium.Marker(
        location = 보호구역.loc[i, ['보호구역_위도', '보호구역_경도']],
        radius = 300,
        tooltip = 보호구역.loc[i,'시설명']
    ).add_to(m2)
for i in protect_spot.index:
    folium.Circle(
        location = 보호구역.loc[i, ['보호구역_위도', '보호구역_경도']],
        radius = 300,
        width = 0.5,
        color='green',
        tooltip = 보호구역.loc[i,'시설종류']
    ).add_to(m2)        
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
### ㅅ

# %%
center = [37.163619, 127.049883]
m = folium.Map(location=center, tiles='openstreetmap', zoom_start=13, fill_color='BuPu') #'cartodbpositron'
for i in protect_spot.index:
    folium.Marker(
        location = 보호구역.loc[i, ['보호구역_위도', '보호구역_경도']],
        radius = 300,
        tooltip = 보호구역.loc[i,'시설명']
    ).add_to(m)

for i in protect_spot.index:
    folium.Circle(
        location = 보호구역.loc[i, ['보호구역_위도', '보호구역_경도']],
        radius = 300,
        width = 0.5,
        color='green',
        tooltip = 보호구역.loc[i,'시설종류']
    ).add_to(m)        
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
child.values[0][1] # 경도
child.values[0][2] # 위도
a = []
for i in special:
    print(special.values[0][1],special.values[0][2])
# Out:
# 127.01752140000002 37.176761799999994
# 127.01752140000002 37.176761799999994
# 127.01752140000002 37.176761799999994

# %%
locs_geometry = [Point(xy) for xy in zip(보호구역.보호구역_경도,보호구역.보호구역_위도)]
# Out:
# [<shapely.geometry.point.Point at 0x7f1c2e840400>,
#  <shapely.geometry.point.Point at 0x7f1c2e840470>,
#  <shapely.geometry.point.Point at 0x7f1c2e8406a0>,
#  <shapely.geometry.point.Point at 0x7f1c2e840710>,
#  <shapely.geometry.point.Point at 0x7f1c2e840780>,
#  <shapely.geometry.point.Point at 0x7f1c2e8407f0>,
#  <shapely.geometry.point.Point at 0x7f1c2e840860>,
#  <shapely.geometry.point.Point at 0x7f1c2e8408d0>,
#  <shapely.geometry.point.Point at 0x7f1c2e840940>,
#  <shapely.geometry.point.Point at 0x7f1c2e8409b0>,
#  <shapely.geometry.point.Point at 0x7f1c2e840a20>,
#  <shapely.geometry.point.Point at 0x7f1c2e840a90>,
#  <shapely.geometry.point.Point at 0x7f1c2e840b00>,
#  <shapely.geometry.point.Point at 0x7f1c2e840b70>,
#  <shapely.geometry.point.Point at 0x7f1c2e840be0>,
#  <shapely.geometry.point.Point at 0x7f1c2e840c50>,
#  <shapely.geometry.point.Point at 0x7f1c2e840cc0>,
#  <shapely.geometry.point.Point at 0x7f1c2e8e3a20>,
#  <shapely.geometry.point.Point at 0x7f1c2e840550>,
#  <shapely.geometry.point.Point at 0x7f1c2e840da0>,
#  <shapely.geometry.point.Point at 0x7f1c2e840e10>,
#  <shapely.geometry.point.Point at 0x7f1c2e840e80>,
#  <shapely.geometry.point.Point at 0x7f1c2e840ef0>,
#  <shapely.geometry.point.Point at 0x7f1c2e840f60>,
#  <shapely.geometry.point.Point at 0x7f1c2e840fd0>,
#  <shapely.geometry.point.Point at 0x7f1c2e9ad780>,
#  <shapely.geometry.point.Point at 0x7f1c2e9ad8d0>,
#  <shapely.geometry.point.Point at 0x7f1c2e9ad320>,
#  <shapely.geometry.point.Point at 0x7f1c2e9ad550>,
#  <shapely.geometry.point.Point at 0x7f1c2e833b00>,
#  <shapely.geometry.point.Point at 0x7f1c2e833c50>,
#  <shapely.geometry.point.Point at 0x7f1c2e833da0>,
#  <shapely.geometry.point.Point at 0x7f1c2e833b70>,
#  <shapely.geometry.point.Point at 0x7f1c2e833e80>,
#  <shapely.geometry.point.Point at 0x7f1c2e833ef0>,
#  <shapely.geometry.point.Point at 0x7f1c2e833f60>,
#  <shapely.geometry.point.Point at 0x7f1c2e833fd0>,
#  <shapely.geometry.point.Point at 0x7f1c2e8336a0>,
#  <shapely.geometry.point.Point at 0x7f1c2e833710>,
#  <shapely.geometry.point.Point at 0x7f1c2e833780>,
#  <shapely.geometry.point.Point at 0x7f1c2e8337f0>,
#  <shapely.geometry.point.Point at 0x7f1c2e833860>,
#  <shapely.geometry.point.Point at 0x7f1c2e8338d0>,
#  <shapely.geometry.point.Point at 0x7f1c2e833940>,
#  <shapely.geometry.point.Point at 0x7f1c2e8339b0>,
#  <shapely.geometry.point.Point at 0x7f1c2e833a20>,
#  <shapely.geometry.point.Point at 0x7f1c2e833a90>,
#  <shapely.geometry.point.Point at 0x7f1c2e92ea90>,
#  <shapely.geometry.point.Point at 0x7f1c2e94ac50>,
#  <shapely.geometry.point.Point at 0x7f1c2e844550>,
#  <shapely.geometry.point.Point at 0x7f1c2e8445c0>,
#  <shapely.geometry.point.Point at 0x7f1c2e8444e0>,
#  <shapely.geometry.point.Point at 0x7f1c2e844390>,
#  <shapely.geometry.point.Point at 0x7f1c2e844080>,
#  <shapely.geometry.point.Point at 0x7f1c2e8440f0>,
#  <shapely.geometry.point.Point at 0x7f1c2e844160>,
#  <shapely.geometry.point.Point at 0x7f1c2e8441d0>,
#  <shapely.geometry.point.Point at 0x7f1c2e844240>,
#  <shapely.geometry.point.Point at 0x7f1c2e8442b0>,
#  <shapely.geometry.point.Point at 0x7f1c2e8397f0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839080>,
#  <shapely.geometry.point.Point at 0x7f1c2e8390f0>,
#  <shapely.geometry.point.Point at 0x7f1c2e8392b0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839160>,
#  <shapely.geometry.point.Point at 0x7f1c2e8391d0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839630>,
#  <shapely.geometry.point.Point at 0x7f1c2e8394e0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839320>,
#  <shapely.geometry.point.Point at 0x7f1c2e839780>,
#  <shapely.geometry.point.Point at 0x7f1c2e839710>,
#  <shapely.geometry.point.Point at 0x7f1c2e839400>,
#  <shapely.geometry.point.Point at 0x7f1c2e839860>,
#  <shapely.geometry.point.Point at 0x7f1c2e8398d0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839940>,
#  <shapely.geometry.point.Point at 0x7f1c2e8399b0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839a20>,
#  <shapely.geometry.point.Point at 0x7f1c2e839a90>,
#  <shapely.geometry.point.Point at 0x7f1c2e839b00>,
#  <shapely.geometry.point.Point at 0x7f1c2e839b70>,
#  <shapely.geometry.point.Point at 0x7f1c2e839be0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839c50>,
#  <shapely.geometry.point.Point at 0x7f1c2e839cc0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839d30>,
#  <shapely.geometry.point.Point at 0x7f1c2e839da0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839e10>,
#  <shapely.geometry.point.Point at 0x7f1c2e839e80>,
#  <shapely.geometry.point.Point at 0x7f1c2e839ef0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839f60>,
#  <shapely.geometry.point.Point at 0x7f1c2e839fd0>,
#  <shapely.geometry.point.Point at 0x7f1c2e839390>,
#  <shapely.geometry.point.Point at 0x7f1c2e839550>]

# %%
locs_geometry[0]

# %%
보호구역['보호구역도로폭'].value_counts().sort_index(ascending=False)
# Out:
# 25     1
# 22     1
# 20     1
# 18     3
# 17     2
# 15     4
# 13     3
# 12    16
# 9      1
# 7      3
# 6     37
# 5      5
# 4      8
# 3      6
# Name: 보호구역도로폭, dtype: int64

# %%
보호구역['보호구역도로폭'].value_counts().sort_index().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# 오산시 위도/경도
# 위도 / 경도 : 337.163619, 127.049883
center = [37.163619, 127.049883]
# Out:
# 4466

# %%
acc1 = 교통사고grid[교통사고grid['accident_cnt'] ==1 ]
center = [37.163619, 127.049883]
m = folium.Map(location=center, tiles='openstreetmap', zoom_start=12.8) #'cartodbpositron'
folium.GeoJson(acc2['geometry']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 24 / 25 / 26. 교통량
#
# ### 혼잡시간강도
# - 전체차량의 총 통행시간 중 교통혼잡을 경험한 차량들의 총 통행시간 비율
#
# ### 혼잡빈도강도
# - 전체차량 대수 중 혼잡을 경험한 차량대수 비율

# %%
교통량 = pd.read_csv('24.평일_전일,시간대별_오산시_추정교통량_Level6.csv')
빈도강도 = pd.read_csv('25.평일_전일_오산시_혼잡빈도강도_Level6.csv')
시간강도 = pd.read_csv('26.평일_전일_오산시_혼잡시간강도_Level6.csv')
# Out:
# /opt/app-root/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
교통량.head()
# Out:
#    상세도로망_LinkID  도로등급   링크길이               도로명  시도명 시군구명 읍면동명 시간적범위 평일주말  \
# 0   57137697901   101  0.093  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동     0   평일
# 1   57135249601   101  0.324  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동     0   평일
# 2   57135250601   101  0.333  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동     0   평일
# 3   57137696601   101  0.372  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동     0   평일
# 4   57137697701   101  0.667  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동     0   평일
#
#    전체 추정교통량  승용차 추정교통량  버스 추정교통량  화물차 추정교통량
# 0    268.55     193.43     11.99      63.13
# 1     21.98      15.48      0.75       5.74
# 2     15.77       9.55      1.50       4.73
# 3    179.55     135.99      5.22      38.35
# 4    267.91     192.96     11.96      62.99

# %%
교통량.groupby('도로명')['전체 추정교통량'].mean().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='도로명'>

# %%
교통량.groupby('도로명')['전체 추정교통량'].mean().sort_values(ascending=False).head(20)
# Out:
# 도로명
# 경부고속도로              6665.515200
# 수도권제2순환고속도로(봉담동탄    1453.304813
# 서부로                 1323.699340
# 경기대로                1250.698690
# 문시로                 1199.500688
# 오산화성고속도로            1057.491778
# 동부대로                1043.777367
# 가장로                  937.970046
# 경기동로                 926.344037
# 성호대로                 830.111280
# 북삼미로                 752.620738
# 원동로                  715.131976
# 독산성로                 646.130161
# 남부대로                 630.425095
# 평택화성고속도로             601.398400
# 현충로                  600.685708
# 독산성로310번길            581.757767
# 문헌공로                 576.543267
# 청학로                  540.205005
# 오산로                  502.011958
# Name: 전체 추정교통량, dtype: float64

# %%
빈도강도.head()
# Out:
#    상세도로망_LinkID  도로등급   링크길이               도로명  시도명 시군구명 읍면동명 시간적범위 평일주말  \
# 0   57125499201   101  1.238            경부고속도로  경기도  오산시  대원동    전일   평일
# 1   57125499001   101  1.335            경부고속도로  경기도  오산시  대원동    전일   평일
# 2   57137697901   101  0.093  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동    전일   평일
# 3   57135249601   101  0.324  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동    전일   평일
# 4   57135250601   101  0.333  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동    전일   평일
#
#    혼잡빈도강도
# 0   49.10
# 1   70.67
# 2   42.61
# 3   96.75
# 4   99.95

# %%
빈도강도.혼잡빈도강도.sort_values(ascending=False)
# Out:
# 3031    100.0
# 2314    100.0
# 2206    100.0
# 391     100.0
# 379     100.0
#         ...
# 362       0.0
# 204       0.0
# 2494      0.0
# 2144      0.0
# 2221      0.0
# Name: 혼잡빈도강도, Length: 3032, dtype: float64

# %%
시간강도.head()
# Out:
#    상세도로망_LinkID  도로등급   링크길이               도로명  시도명 시군구명 읍면동명 시간적범위 평일주말  \
# 0   57125499201   101  1.238            경부고속도로  경기도  오산시  대원동    전일   평일
# 1   57125499001   101  1.335            경부고속도로  경기도  오산시  대원동    전일   평일
# 2   57137697901   101  0.093  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동    전일   평일
# 3   57135249601   101  0.324  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동    전일   평일
# 4   57135250601   101  0.333  수도권제2순환고속도로(봉담동탄  경기도  오산시  세마동    전일   평일
#
#    혼잡시간강도
# 0   59.66
# 1   77.13
# 2   50.79
# 3   99.75
# 4   99.99

# %%
CCTV = pd.read_csv('20.오산시_CCTV설치현황.csv')

# %%
CCTV.head(50)
# Out:
#    CCTV 유형코드      설치위치_도로명주소    설치위치_위도     설치위치_경도
# 0          A   성호대로55번길 31-2  37.151836  127.067541
# 1          A     성호대로93번길 45  37.152812  127.071702
# 2          C     성호대로93번길 26  37.151167  127.071677
# 3          A   운천로165번길 52-1  37.157164  127.075991
# 4          A      운천로165번길 5  37.156461  127.077273
# 5          A          오산로 63  37.132458  127.068957
# 6          A   성호대로33번길 16-7  37.151525  127.065887
# 7          C        성산새싹길 13  37.150370  127.065719
# 8          A     성호대로40번길 10  37.148432  127.065522
# 9          A      궐동로69번길 38  37.158049  127.064233
# 10         A       궐동로69번길 9  37.157150  127.062397
# 11         A         궐리사로 92  37.158025  127.062381
# 12         A          궐동로 43  37.157584  127.059023
# 13         A  궐리사로46번길 60-13  37.159524  127.055925
# 14         A      법원로15번길 38  37.155792  127.053424
# 15         C      현충로72번길 24  37.160448  127.073239
# 16         A       오산로 298-1  37.153541  127.068786
# 17         C         성호새싹길 8  37.149657  127.070278
# 18         A         운천로 154  37.156077  127.075912
# 19         A        부원로 67-6  37.142939  127.086148
# 20         A          밀머리 45  37.137802  127.075148
# 21         A        밀머리로 101  37.136143  127.081281
# 22         C      대원로29번길 16  37.147547  127.071512
# 23         A     오산로212번길 15  37.145807  127.070007
# 24         A       성호대로 26-7  37.148437  127.064452
# 25         A             NaN  37.147976  127.066583
# 26         A     오산로358번길 11  37.158861  127.068047
# 27         A         궐리사로 81  37.158543  127.061117
# 28         A      궐동로69번길 18  37.156788  127.063403
# 29         A          궐동로 21  37.158224  127.056585
# 30         A         청학로 125  37.160053  127.064241
# 31         A     청학로147번길 45  37.163724  127.060518
# 32         A        발안로 1354  37.141273  127.047209
# 33         C       시장58번길 10  37.154019  127.070220
# 34         A     오산로289번길 16  37.153763  127.067929
# 35         A           대원로 2  37.146268  127.068565
# 36         B     오산로132번길 28  37.138159  127.071475
# 37         B   오산로62번길 15-10  37.131757  127.071027
# 38         C             NaN  37.134909  127.068785
# 39         A     궐리사로29번길 26  37.161404  127.057271
# 40         A   법원로15번길 15-11  37.155063  127.054920
# 41         C      궐리사로46번길 3  37.159277  127.057249
# 42         A             NaN  37.152953  127.058232
# 43         A        현충로 13-7  37.163670  127.069780
# 44         A       수청로 30-13  37.173000  127.059664
# 45         C      수청로8번길 3-1  37.171089  127.058773
# 46         A             NaN  37.161266  127.069526
# 47         C          가수로 50  37.147591  127.046913
# 48         A             NaN  37.160471  127.057304
# 49         A     궐리사로29번길 48  37.159979  127.059271
